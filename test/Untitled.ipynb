# %%
import packing
import utils
from packing import test

import itertools

# %%
orderlines = utils.read_problem("./test/testproblem.csv")

# %%
cases = tuple(itertools.chain(
    orderlines[0].cases,
    orderlines[1].cases, 
    orderlines[2].cases, 
    orderlines[3].cases,
    orderlines[6].cases,
))

# %%
# %%time
test(packing.MRBL, cases, (120,80))
# Out:
# CPU times: user 170 ms, sys: 839 µs, total: 171 ms
# Wall time: 169 ms

# %%
# %%time
packing.MRBL(cases, (120,80))
# Out:
# CPU times: user 6.22 ms, sys: 0 ns, total: 6.22 ms
# Wall time: 6.08 ms
# True

# %%
# %%time
packing.GBAF(cases, (120,80), splitting="shorterleftover")
# Out:
# CPU times: user 350 µs, sys: 65 µs, total: 415 µs
# Wall time: 422 µs
# True

# %%
# %%time
test(packing.GBAF, cases, (120,80), splitting="shorteraxis")
# Out:
# CPU times: user 224 ms, sys: 1.04 ms, total: 225 ms
# Wall time: 223 ms

# %%
# %%time
test(packing.SNF, cases, (120,80))
# Out:
# CPU times: user 172 ms, sys: 7.2 ms, total: 179 ms
# Wall time: 180 ms

# %%
# %%time
packing.SNF(cases, (120,80))
# Out:
# CPU times: user 107 µs, sys: 23 µs, total: 130 µs
# Wall time: 135 µs
# True

# %%
# %%time
test(packing.SFF, cases, (120,80))
# Out:
# CPU times: user 140 ms, sys: 7.42 ms, total: 148 ms
# Wall time: 146 ms

# %%
# %%time
test(packing.SBWF, cases, (120,80))
# Out:
# CPU times: user 246 ms, sys: 8.68 ms, total: 254 ms
# Wall time: 252 ms

# %%
# %%time
test(packing.SWWF, cases, (120,80))
# Out:
# CPU times: user 190 ms, sys: 6.36 ms, total: 197 ms
# Wall time: 196 ms

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/Scaricati/binpacking/src/packing.py in test(algorithm, cases, layersize, figsize, **kwargs)
#       9
#      10 def test (algorithm, cases, layersize, figsize=(10,6), **kwargs):
# ---> 11     suc = algorithm(cases, layersize, **kwargs)
#      12     if not suc:
#      13         print("Unsuccesful packing.")
#
# ~/Scaricati/binpacking/src/packing.py in GBAF(cases, layersize, splitting)
#     214
#     215     for case in cases:
# --> 216         F.sort(key=lambda s: s.sizex * s.sizey)
#     217         for i in range(len(F)):
#     218             space = F[i]
#
# ~/Scaricati/binpacking/src/packing.py in <lambda>(s)
#     214
#     215     for case in cases:
# --> 216         F.sort(key=lambda s: s.sizex * s.sizey)
#     217         for i in range(len(F)):
#     218             space = F[i]
#
# ...
